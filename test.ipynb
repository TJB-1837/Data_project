# %%
import pandas as pd
import numpy as np
import plotly.express as px

df = pd.read_csv("data/raw/dataset/global_air_quality_data_10000.csv")
df["Date"] = pd.to_datetime(df["Date"])
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         10000 non-null  object
#  1   Country      10000 non-null  object
#  2   Date         10000 non-null  datetime64[ns]
#  3   PM2.5        10000 non-null  float64
#  4   PM10         10000 non-null  float64
#  5   NO2          10000 non-null  float64
#  6   SO2          10000 non-null  float64
#  7   CO           10000 non-null  float64
#  8   O3           10000 non-null  float64
#  9   Temperature  10000 non-null  float64
#  10  Humidity     10000 non-null  float64
#  11  Wind Speed   10000 non-null  float64
# dtypes: datetime64[ns](1), float64(9), object(2)
# memory usage: 937.6+ KB
# None

# %%
print(df["Date"].dt.date.value_counts().sort_index())
# Out:
# Date
# 2023-01-01    19
# 2023-01-02    32
# 2023-01-03    25
# 2023-01-04    31
# 2023-01-05    26
#               ..
# 2023-12-24    39
# 2023-12-25    31
# 2023-12-26    27
# 2023-12-27    27
# 2023-12-28    25
# Name: count, Length: 336, dtype: int64

# %%
print(df["Country"].unique())
for i
# Out:
# ['Thailand' 'Turkey' 'Brazil' 'India' 'France' 'USA' 'Japan' 'UK'
#  'South Korea' 'Egypt' 'Mexico' 'Germany' 'China' 'Australia' 'UAE'
#  'Canada' 'Spain' 'South Africa' 'Russia']

# %%
countries ={}
for i,country in enumerate(df["Country"].unique()) : 
    df_country = df[df["Country"]==country]
    mean_temp = df_country["Temperature"].mean()
    countries[country] = mean_temp

print(countries)
# Out:
# {'Thailand': np.float64(14.727615230460922), 'Turkey': np.float64(15.202113821138212), 'Brazil': np.float64(16.190183299389002), 'India': np.float64(14.231444444444444), 'France': np.float64(14.618527607361965), 'USA': np.float64(14.688752598752599), 'Japan': np.float64(13.94295315682281), 'UK': np.float64(15.757607361963188), 'South Korea': np.float64(15.272375478927204), 'Egypt': np.float64(14.666882352941178), 'Mexico': np.float64(15.412591792656585), 'Germany': np.float64(15.033930635838152), 'China': np.float64(14.107520491803282), 'Australia': np.float64(14.120205761316873), 'UAE': np.float64(14.850923076923078), 'Canada': np.float64(15.148610038610038), 'Spain': np.float64(15.376138996138996), 'South Africa': np.float64(14.452667946257199), 'Russia': np.float64(15.510705394190872)}
